# %%
import pandas as pd

# %%
data=pd.read_csv("2016.csv")
data
# Out:
#                                           Station Name State Name  temp_min  \
# 0                                  YAMUNA AT WAZIRABAD      DELHI      16.7
# 1                                 YAMUNA AT NIZAMUDDIN      DELHI      17.1
# 2                  OKHLA BRIDGE (INLET OF\nAGRA CANAL)      DELHI      17.3
# 3               YAMUNA AT OKHLA\nA/M OF SHAHDARA DRAIN      DELHI      19.4
# 4                                 MAHI AT UMETA BRIDGE    GUJARAT      19.0
# 5                                       MAHI AT MUJPUR    GUJARAT      27.0
# 6                                      MAHI AT SEVALIA    GUJARAT      24.0
# 7                                        MAHI AT VASAD    GUJARAT      20.0
# 8            MAHI NEAR RAJASTHAN BORDER\nAT KADANA DAM    GUJARAT      29.0
# 9     MAHI AFTER CONF. WITH ANAS AT\nPARDI (BANASWADA)    GUJARAT      30.0
# 10                                      MAHI AT VIRPUR    GUJARAT      28.0
# 11                              MAHI AT SHERKHI BRIDGE    GUJARAT      26.0
# 12       ANAS AT\nDAHOD,(KUSHALGARH),DIST.\nPANCHMAHAL    GUJARAT      30.0
# 13                                   PANAM AT LUNAWADA    GUJARAT      28.0
# 14          VISHWAMITRI DOWNSTREAM AT\nKHALIPUR VILLAG    GUJARAT      26.0
# 15   VISHWAMITRI, UPSTREAM AT\nASOD BRIDGE AT NH-8 ...    GUJARAT      26.0
# 16                             SABARMATI AT DHAROI DAM    GUJARAT      27.0
# 17              SABARMATI AT AHMEDABAD AT\nV.N. BRIDGE    GUJARAT      25.0
# 18                          SABARMATI AT KHEROJ BRIDGE    GUJARAT      25.0
# 19    SABARMATI A/C WITH MESHWA\nAT VAUTHA NEAR DHOKLA    GUJARAT      26.0
# 20   SABARMATI AT GANDHI NAGAR\nCHILODA BRIDGE,LEKA...    GUJARAT      28.0
# 21   SABARMATI AT VILL. MIROLI\nTALUKA DASCROI,AHME...    GUJARAT      28.0
# 22              SABARMATI AT RAILWAY BRIDGE\nAHMEDABAD    GUJARAT      25.0
# 23   SABARMATI AT MAHUDI JAIN\nTEMPLE, 150 KM. FORM...    GUJARAT      27.0
# 24                         SABARMATI AT HANSAOL BRIDGE    GUJARAT      25.0
# 25            MESHWA NEAR RAJASTHAN\nBORDER AT SAMLAJI    GUJARAT      27.0
# 26                                     SHEDHI AT KHEDA    GUJARAT      25.0
# 27                              NARMADA AT GARUDESHWAR    GUJARAT      26.0
# 28                                  NARMADA AT CHANDOD    GUJARAT      25.0
# 29                                  NARMADA AT PANETHA    GUJARAT      26.0
# ..                                                 ...        ...       ...
# 757                   KAMALA AT BENIPATTI\n(MADHUBANI)      BIHAR      15.0
# 758                                KAMALA AT DARBHANGA      BIHAR      17.0
# 759                        MANUSMARAT RIGA,\nSITAMARHI      BIHAR      18.0
# 760                      KOSHI AT KURSHELA AT\nKATIHAR      BIHAR      14.0
# 761                                 KOSHI AT MADHEPURA      BIHAR      14.0
# 762                                      DAHA AT SIWAN      BIHAR      15.0
# 763                                  DAHA D/S SASAMUSA      BIHAR      16.0
# 764                        DAHA AT ITWA BRIDGE,\nSIWAN      BIHAR      15.0
# 765                                 DHOUS AT MADHUBANI      BIHAR      18.0
# 766                                  FARMAR AT JOGBANI      BIHAR      14.0
# 767                              RAM REKHAAT HARINAGAR      BIHAR      16.0
# 768                                     SIRSA AT RUXOL      BIHAR      16.0
# 769                                  SONE NEAR BANZARI      BIHAR      16.0
# 770                             SONE RIVER AT BAHIYARA      BIHAR      22.0
# 771                      SONE RIVER AT NASIRIGANJ\nDAM      BIHAR      18.0
# 772     BAGMATI AT MUZAFFARPUR-\nSITAMARHI ROAD BRIDGE      BIHAR      16.0
# 773       BAGMATI AT DARBANGA,\nSAMASTIPUR ROAD BRIDGE      BIHAR      20.0
# 774                                   DAHA AT MEERGANJ      BIHAR      15.0
# 775           GANDAK U/S ROAD BRIDGE\nMUZAFFARPUR (NH)      BIHAR      17.0
# 776  GANDAK GOPALGANJ PIPRAKOTHI\nROAD BRIDGE (DUMA...      BIHAR      17.0
# 777  U/S HARBORA BEFORE SUGAR MILL\nNEAR ROAD BRIDG...      BIHAR      16.0
# 778                                KAMALA AT JAYNAGAR,      BIHAR      20.0
# 779                                   KOSHI AT BEERPUR      BIHAR      14.0
# 780                U/S MANUSMAR RIVER AT BAKHARI\nRIGA      BIHAR      15.0
# 781                  POONPUN NEAR POONPUN RAIL\nBRIDGE      BIHAR      12.0
# 782                   POONPUN NEAR KINZER ROAD\nBRIDGE      BIHAR      14.0
# 783                             RAMREKHA U/S HARINAGAR      BIHAR      16.0
# 784         SIKRAHNA AT LAUREA, HARINAGAR\nROAD BRIDGE      BIHAR      17.0
# 785                     SIRSA D/S RAXAUL (KOERIA TOLA)      BIHAR      16.0
# 786   MAHANANDA AT THAKURGANJ,\nKISHANGANJ ROAD BRIDGE      BIHAR      14.0
#
#      temp_max   bact grow  oxy_min  oxy_max  ph_min  ph_max
# 0        32.8           1      5.1    13.50     7.2     8.0
# 1        30.9           0      0.4     2.60     7.1     7.9
# 2        30.4           0      0.4     1.80     7.1     7.8
# 3        31.8           0      0.1     1.60     7.0     7.9
# 4        30.0           1      5.3     9.00     7.3     8.5
# 5        33.0           1      6.0     9.00     8.0     8.6
# 6        30.0           1      7.3     9.00     7.3     8.5
# 7        29.0           1      4.9     9.10     7.3     8.5
# 8        32.0           1      6.2     9.00     7.1     8.5
# 9        33.0           1      5.6     8.90     7.5     8.5
# 10       32.0           0      3.0     8.90     7.8     8.3
# 11       31.0           1      6.0     9.00     7.1     8.7
# 12       32.0           0      3.8     8.90     7.6     8.5
# 13       32.0           1      5.6     9.00     7.0     8.1
# 14       30.0           0      0.8     2.20     7.8     8.3
# 15       30.0           1      4.9     9.20     7.7     8.9
# 16       33.0           1      5.5     8.04     7.5     8.0
# 17       29.0           0      1.2     7.32     7.4     8.5
# 18       27.0           0      4.1     7.70     7.4     8.4
# 19       30.0           0      1.1     7.20     7.9     8.5
# 20       32.0           1      5.0     8.20     7.4     8.8
# 21       33.0           1      7.1     7.10     8.0     8.4
# 22       28.0           0      3.4     7.20     7.8     8.4
# 23       29.0           0      4.0     8.80     7.3     8.3
# 24       28.0           0      4.3     7.60     8.0     8.0
# 25       27.0           1      6.6     6.60     7.3     8.1
# 26       32.0           0      1.2     9.00     7.7     8.4
# 27       30.0           1      7.1     7.95     7.1     8.5
# 28       30.0           1      5.8     8.50     7.0     8.4
# 29       32.0           1      7.0     8.20     7.5     8.3
# ..        ...         ...      ...      ...     ...     ...
# 757      30.0           1      7.4    10.00     7.6     8.9
# 758      30.0           1      7.0     8.60     7.3     8.2
# 759      32.0           1      6.7     8.00     6.8     8.2
# 760      31.0           1      6.3     9.10     6.6     7.6
# 761      35.0           1      6.2     9.00     7.2     7.6
# 762      30.0           1      5.0     9.80     7.1     8.4
# 763      30.0           1      6.0     9.50     7.0     7.8
# 764      29.0           1      6.9     9.20     7.2     8.4
# 765      30.0           1      6.0     9.40     7.3     8.9
# 766      29.0           1      5.6     8.60     6.6     7.6
# 767      32.0           1      6.4     7.60     6.9     7.9
# 768      33.0           1      6.4     6.40     7.0     7.7
# 769      34.0           1      7.2     9.20     7.2     8.6
# 770      30.0           1      5.2     9.00     7.5     8.2
# 771      33.0           1      7.1     9.60     7.4     8.5
# 772      35.0           1      7.2     8.80     6.9     8.2
# 773      34.0           1      7.4     9.10     7.4     8.8
# 774      30.0           1      6.5     9.60     7.5     8.2
# 775      33.0           1      7.5     8.80     7.2     8.4
# 776      30.0           1      7.0     9.80     7.3     8.6
# 777      30.0           1      7.2     8.60     7.1     8.3
# 778      29.0           1      7.5    10.00     7.7     8.5
# 779      35.0           0      6.6     8.90     7.2     7.8
# 780      32.0           1      7.0     8.60     7.0     8.6
# 781      30.0           1      6.5     9.60     7.0     8.6
# 782      32.0           1      6.5    10.00     7.1     8.5
# 783      32.0           1      6.9     8.00     7.1     7.9
# 784      36.0           0      7.0     8.60     7.2     7.8
# 785      36.0           0      2.8     6.30     7.2     7.8
# 786      28.0           1      6.1     8.50     6.5     7.6
#
# [787 rows x 9 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
states=data['State Name'].tolist()
states
# Out:
# ['DELHI',
#  'DELHI',
#  'DELHI',
#  'DELHI',
#  'GUJARAT',
#  'GUJARAT',
#  'GUJARAT',
#  'GUJARAT',
#  'GUJARAT',
#  'GUJARAT',
#  'GUJARAT',
#  'GUJARAT',
#  'GUJARAT',
#  'GUJARAT',
#  'GUJARAT',
#  'GUJARAT',
#  'GUJARAT',
#  'GUJARAT',
#  'GUJARAT',
#  'GUJARAT',
#  'GUJARAT',
#  'GUJARAT',
#  'GUJARAT',
#  'GUJARAT',
#  'GUJARAT',
#  'GUJARAT',
#  'GUJARAT',
#  'GUJARAT',
#  'GUJARAT',
#  'GUJARAT',
#  'GUJARAT',
#  'GUJARAT',
#  'GUJARAT',
#  'GUJARAT',
#  'GUJARAT',
#  'GUJARAT',
#  'GUJARAT',
#  'GUJARAT',
#  'GUJARAT',
#  'GUJARAT',
#  'GUJARAT',
#  'HARYANA',
#  'HARYANA',
#  'HARYANA',
#  'HIMACHAL PRADESH',
#  'HIMACHAL PRADESH',
#  'HIMACHAL PRADESH',
#  'HIMACHAL PRADESH',
#  'HIMACHAL PRADESH',
#  'HIMACHAL PRADESH',
#  'HIMACHAL PRADESH',
#  'HIMACHAL PRADESH',
#  'HIMACHAL PRADESH',
#  'HIMACHAL PRADESH',
#  'HIMACHAL PRADESH',
#  'HIMACHAL PRADESH',
#  'HIMACHAL PRADESH',
#  'HIMACHAL\nPRADESH',
#  'HIMACHAL\nPRADESH',
#  'HIMACHAL\nPRADESH',
#  'HIMACHAL\nPRADESH',
#  'HIMACHAL\nPRADESH',
#  'HIMACHAL\nPRADESH',
#  'HIMACHAL\nPRADESH',
#  'HIMACHAL\nPRADESH',
#  'HIMACHAL\nPRADESH',
#  'HIMACHAL\nPRADESH',
#  'HIMACHAL\nPRADESH',
#  'HIMACHAL\nPRADESH',
#  'HIMACHAL\nPRADESH',
#  'HIMACHAL\nPRADESH',
#  'HIMACHAL\nPRADESH',
#  'HIMACHAL\nPRADESH',
#  'HIMACHAL\nPRADESH',
#  'HIMACHAL\nPRADESH',
#  'HIMACHAL\nPRADESH',
#  'HIMACHAL\nPRADESH',
#  'HIMACHAL\nPRADESH',
#  'HIMACHAL\nPRADESH',
#  'HIMACHAL\nPRADESH',
#  'HIMACHAL\nPRADESH',
#  'HIMACHAL\nPRADESH',
#  'HIMACHAL\nPRADESH',
#  'HIMACHAL\nPRADESH',
#  'HIMACHAL\nPRADESH',
#  'HIMACHAL\nPRADESH',
#  'HIMACHAL\nPRADESH',
#  'HIMACHAL\nPRADESH',
#  'HIMACHAL\nPRADESH',
#  'HIMACHAL\nPRADESH',
#  'HIMACHAL\nPRADESH',
#  'HIMACHAL\nPRADESH',
#  'HIMACHAL\nPRADESH',
#  'JAMMU &\nKASHMIR',
#  'JAMMU &\nKASHMIR',
#  'JAMMU &\nKASHMIR',
#  'JAMMU &\nKASHMIR',
#  'JAMMU &\nKASHMIR',
#  'JAMMU &\nKASHMIR',
#  'JAMMU &\nKASHMIR',
#  'JAMMU &\nKASHMIR',
#  'JAMMU &\nKASHMIR',
#  'JAMMU &\nKASHMIR',
#  'JAMMU &\nKASHMIR',
#  'JAMMU &\nKASHMIR',
#  'JAMMU &\nKASHMIR',
#  'JAMMU &\nKASHMIR',
#  'JAMMU &\nKASHMIR',
#  'JAMMU &\nKASHMIR',
#  'JAMMU &\nKASHMIR',
#  'JAMMU &\nKASHMIR',
#  'JAMMU &\nKASHMIR',
#  'JAMMU &\nKASHMIR',
#  'JAMMU &\nKASHMIR',
#  'JAMMU &\nKASHMIR',
#  'JAMMU &\nKASHMIR',
#  'JAMMU &\nKASHMIR',
#  'JAMMU &\nKASHMIR',
#  'JAMMU &\nKASHMIR',
#  'JAMMU &\nKASHMIR',
#  'JAMMU &\nKASHMIR',
#  'JAMMU &\nKASHMIR',
#  'JAMMU &\nKASHMIR',
#  'JAMMU &\nKASHMIR',
#  'JAMMU &\nKASHMIR',
#  'JAMMU &\nKASHMIR',
#  'JAMMU &\nKASHMIR',
#  'JAMMU &\nKASHMIR',
#  'JAMMU &\nKASHMIR',
#  'JHARKHAND',
#  'JHARKHAND',
#  'JHARKHAND',
#  'JHARKHAND',
#  'JHARKHAND',
#  'JHARKHAND',
#  'JHARKHAND',
#  'JHARKHAND',
#  'JHARKHAND',
#  'JHARKHAND',
#  'JHARKHAND',
#  'JHARKHAND',
#  'JHARKHAND',
#  'JHARKHAND',
#  'JHARKHAND',
#  'JHARKHAND',
#  'JHARKHAND',
#  'JHARKHAND',
#  'JHARKHAND',
#  'JHARKHAND',
#  'JHARKHAND',
#  'JHARKHAND',
#  'JHARKHAND',
#  'JHARKHAND',
#  'JHARKHAND',
#  'JHARKHAND',
#  'JHARKHAND',
#  'JHARKHAND',
#  'JHARKHAND',
#  'JHARKHAND',
#  'JHARKHAND',
#  'KARNATAKA',
#  'KARNATAKA',
#  'KARNATAKA',
#  'KARNATAKA',
#  'KARNATAKA',
#  'KARNATAKA',
#  'KARNATAKA',
#  'KARNATAKA',
#  'KARNATAKA',
#  'KARNATAKA',
#  'KARNATAKA',
#  'KARNATAKA',
#  'KARNATAKA',
#  'KARNATAKA',
#  'KARNATAKA',
#  'KARNATAKA',
#  'KARNATAKA',
#  'KARNATAKA',
#  'KARNATAKA',
#  'KARNATAKA',
#  'KARNATAKA',
#  'KARNATAKA',
#  'KARNATAKA',
#  'KARNATAKA',
#  'KARNATAKA',
#  'KARNATAKA',
#  'KARNATAKA',
#  'KARNATAKA',
#  'KARNATAKA',
#  'KARNATAKA',
#  'KARNATAKA',
#  'KARNATAKA',
#  'KARNATAKA',
#  'KARNATAKA',
#  'KARNATAKA',
#  'KARNATAKA',
#  'KARNATAKA',
#  'KARNATAKA',
#  'KARNATAKA',
#  'KARNATAKA',
#  'KARNATAKA',
#  'KARNATAKA',
#  'KARNATAKA',
#  'KARNATAKA',
#  'KARNATAKA',
#  'KARNATAKA',
#  'KARNATAKA',
#  'KARNATAKA',
#  'KARNATAKA',
#  'KARNATAKA',
#  'KARNATAKA',
#  'KARNATAKA',
#  'KARNATAKA',
#  'KARNATAKA',
#  'KARNATAKA',
#  'KARNATAKA',
#  'KARNATAKA',
#  'KARNATAKA',
#  'KARNATAKA',
#  'KARNATAKA',
#  'KARNATAKA',
#  'KARNATAKA',
#  'KARNATAKA',
#  'KARNATAKA',
#  'KARNATAKA',
#  'KERALA',
#  'KERALA',
#  'MADHYA PRADESH',
#  'MADHYA PRADESH',
#  'MADHYA PRADESH',
#  'MADHYA PRADESH',
#  'MADHYA PRADESH',
#  'MADHYA PRADESH',
#  'MADHYA PRADESH',
#  'MADHYA PRADESH',
#  'MADHYA PRADESH',
#  'MADHYA PRADESH',
#  'MADHYA PRADESH',
#  'MADHYA PRADESH',
#  'MADHYA PRADESH',
#  'MADHYA PRADESH',
#  'MADHYA PRADESH',
#  'MADHYA PRADESH',
#  'MADHYA PRADESH',
#  'MADHYA PRADESH',
#  'MADHYA PRADESH',
#  'MADHYA PRADESH',
#  'MADHYA PRADESH',
#  'MADHYA PRADESH',
#  'MADHYA PRADESH',
#  'MADHYA PRADESH',
#  'MADHYA PRADESH',
#  'MADHYA PRADESH',
#  'MADHYA PRADESH',
#  'MADHYA PRADESH',
#  'MADHYA PRADESH',
#  'MADHYA PRADESH',
#  'MADHYA PRADESH',
#  'MADHYA PRADESH',
#  'MADHYA PRADESH',
#  'MADHYA PRADESH',
#  'MADHYA PRADESH',
#  'MADHYA PRADESH',
#  'MADHYA PRADESH',
#  'MADHYA PRADESH',
#  'MADHYA PRADESH',
#  'MADHYA PRADESH',
#  'MADHYA PRADESH',
#  'MADHYA PRADESH',
#  'MADHYA PRADESH',
#  'MADHYA PRADESH',
#  'MADHYA PRADESH',
#  'MADHYA PRADESH',
#  'MADHYA PRADESH',
#  'MADHYA PRADESH',
#  'MADHYA PRADESH',
#  'MADHYA PRADESH',
#  'MADHYA PRADESH',
#  'MADHYA PRADESH',
#  'MADHYA PRADESH',
#  'MADHYA PRADESH',
#  'MADHYA PRADESH',
#  'MADHYA PRADESH',
#  'MADHYA PRADESH',
#  'MADHYA PRADESH',
#  'MADHYA PRADESH',
#  'MADHYA PRADESH',
#  'MADHYA PRADESH',
#  'MADHYA PRADESH',
#  'MADHYA PRADESH',
#  'MADHYA PRADESH',
#  'MADHYA PRADESH',
#  'MADHYA PRADESH',
#  'MADHYA PRADESH',
#  'MADHYA PRADESH',
#  'MADHYA PRADESH',
#  'MADHYA PRADESH',
#  'MADHYA PRADESH',
#  'MADHYA PRADESH',
#  'MADHYA PRADESH',
#  'MADHYA PRADESH',
#  'MADHYA PRADESH',
#  'MADHYA PRADESH',
#  'MADHYA PRADESH',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'NAGALAND',
#  'NAGALAND',
#  'NAGALAND',
#  'NAGALAND',
#  'NAGALAND',
#  'NAGALAND',
#  'NAGALAND',
#  'NAGALAND',
#  'ODISHA',
#  'ODISHA',
#  'ODISHA',
#  'ODISHA',
#  'ODISHA',
#  'ODISHA',
#  'ODISHA',
#  'ODISHA',
#  'ODISHA',
#  'ODISHA',
#  'ODISHA',
#  'ODISHA',
#  'ODISHA',
#  'ODISHA',
#  'ODISHA',
#  'ODISHA',
#  'ODISHA',
#  'ODISHA',
#  'ODISHA',
#  'ODISHA',
#  'ODISHA',
#  'ODISHA',
#  'ODISHA',
#  'ODISHA',
#  'ODISHA',
#  'ODISHA',
#  'ODISHA',
#  'ODISHA',
#  'ODISHA',
#  'ODISHA',
#  'ODISHA',
#  'ODISHA',
#  'ODISHA',
#  'ODISHA',
#  'ODISHA',
#  'ODISHA',
#  'ODISHA',
#  'ODISHA',
#  'ODISHA',
#  'ODISHA',
#  'ODISHA',
#  'ODISHA',
#  'PUNJAB',
#  'PUNJAB',
#  'PUNJAB',
#  'PUNJAB',
#  'PUNJAB',
#  'PUNJAB',
#  'PUNJAB',
#  'PUNJAB',
#  'PUNJAB',
#  'PUNJAB',
#  'PUNJAB',
#  'PUNJAB',
#  'PUNJAB',
#  'PUNJAB',
#  'PUNJAB',
#  'PUNJAB',
#  'PUNJAB',
#  'PUNJAB',
#  'PUNJAB',
#  'PUNJAB',
#  'PUNJAB',
#  'PUNJAB',
#  'PUNJAB',
#  'PUNJAB',
#  'RAJASTHAN',
#  'RAJASTHAN',
#  'RAJASTHAN',
#  'RAJASTHAN',
#  'RAJASTHAN',
#  'RAJASTHAN',
#  'RAJASTHAN',
#  'RAJASTHAN',
#  'RAJASTHAN',
#  'RAJASTHAN',
#  'RAJASTHAN',
#  'RAJASTHAN',
#  'RAJASTHAN',
#  'TAMIL NADU',
#  'TAMIL NADU',
#  'TAMIL NADU',
#  'TAMIL NADU',
#  'TAMIL NADU',
#  'TAMIL NADU',
#  'TAMIL NADU',
#  'TAMIL NADU',
#  'TAMIL NADU',
#  'TAMIL NADU',
#  'TAMIL NADU',
#  'TAMIL NADU',
#  'TAMIL NADU',
#  'TAMIL NADU',
#  'TAMIL NADU',
#  'TAMIL NADU',
#  'TAMIL NADU',
#  'TAMIL NADU',
#  'TAMIL NADU',
#  'TAMIL NADU',
#  'TAMIL NADU',
#  'TAMIL NADU',
#  'TAMIL NADU',
#  'TAMIL NADU',
#  'TAMIL NADU',
#  'TAMIL NADU',
#  'TAMIL NADU',
#  'TAMIL NADU',
#  'TAMIL NADU',
#  'TAMIL NADU',
#  'TAMIL NADU',
#  'TELANGANA',
#  'TELANGANA',
#  'TELANGANA',
#  'TELANGANA',
#  'TELANGANA',
#  'TELANGANA',
#  'TELANGANA',
#  'TELANGANA',
#  'TELANGANA',
#  'TELANGANA',
#  'TELANGANA',
#  'TELANGANA',
#  'TELANGANA',
#  'TELANGANA',
#  'TELANGANA',
#  'TELANGANA',
#  'TELANGANA',
#  'TELANGANA',
#  'TELANGANA',
#  'TELANGANA',
#  'TRIPURA',
#  'TRIPURA',
#  'TRIPURA',
#  'UTTAR PRADESH',
#  'UTTAR PRADESH',
#  'UTTAR PRADESH',
#  'UTTAR PRADESH',
#  'UTTAR PRADESH',
#  'UTTAR PRADESH',
#  'UTTAR PRADESH',
#  'UTTAR PRADESH',
#  'UTTAR PRADESH',
#  'UTTAR PRADESH',
#  'UTTAR PRADESH',
#  'UTTAR PRADESH',
#  'UTTAR PRADESH',
#  'UTTAR PRADESH',
#  'UTTAR PRADESH',
#  'UTTAR PRADESH',
#  'UTTAR PRADESH',
#  'UTTAR PRADESH',
#  'UTTAR PRADESH',
#  'UTTAR PRADESH',
#  'UTTAR PRADESH',
#  'UTTAR PRADESH',
#  'UTTAR PRADESH',
#  'UTTAR PRADESH',
#  'UTTAR PRADESH',
#  'UTTAR PRADESH',
#  'UTTAR PRADESH',
#  'UTTAR PRADESH',
#  'UTTAR PRADESH',
#  'UTTAR PRADESH',
#  'UTTAR PRADESH',
#  'UTTAR PRADESH',
#  'UTTAR PRADESH',
#  'UTTAR PRADESH',
#  'UTTAR PRADESH',
#  'UTTAR PRADESH',
#  'UTTAR PRADESH',
#  'UTTAR PRADESH',
#  'UTTAR PRADESH',
#  'UTTAR PRADESH',
#  'UTTAR PRADESH',
#  'UTTAR PRADESH',
#  'UTTAR PRADESH',
#  'UTTAR PRADESH',
#  'UTTAR PRADESH',
#  'UTTAR PRADESH',
#  'UTTAR PRADESH',
#  'UTTAR PRADESH',
#  'UTTAR PRADESH',
#  'UTTAR PRADESH',
#  'UTTAR PRADESH',
#  'UTTARAKHAND',
#  'UTTARAKHAND',
#  'UTTARAKHAND',
#  'UTTARAKHAND',
#  'UTTARAKHAND',
#  'UTTARAKHAND',
#  'UTTARAKHAND',
#  'UTTARAKHAND',
#  'UTTARAKHAND',
#  'UTTARAKHAND',
#  'UTTARAKHAND',
#  'UTTARAKHAND',
#  'UTTARAKHAND',
#  'UTTARAKHAND',
#  'UTTARAKHAND',
#  'UTTARAKHAND',
#  'UTTARAKHAND',
#  'UTTARAKHAND',
#  'UTTARAKHAND',
#  'UTTARAKHAND',
#  'UTTARAKHAND',
#  'UTTARAKHAND',
#  'UTTARAKHAND',
#  'UTTARAKHAND',
#  'UTTARAKHAND',
#  'WEST BENGAL',
#  'WEST BENGAL',
#  'WEST BENGAL',
#  'WEST BENGAL',
#  'WEST BENGAL',
#  'WEST BENGAL',
#  'WEST BENGAL',
#  'WEST BENGAL',
#  'WEST BENGAL',
#  'WEST BENGAL',
#  'WEST BENGAL',
#  'WEST BENGAL',
#  'WEST BENGAL',
#  'WEST BENGAL',
#  'WEST BENGAL',
#  'WEST BENGAL',
#  'WEST BENGAL',
#  'WEST BENGAL',
#  'WEST BENGAL',
#  'WEST BENGAL',
#  'WEST BENGAL',
#  'WEST BENGAL',
#  'WEST BENGAL',
#  'WEST BENGAL',
#  'WEST BENGAL',
#  'WEST BENGAL',
#  'WEST BENGAL',
#  'WEST BENGAL',
#  'WEST BENGAL',
#  'WEST BENGAL',
#  'WEST BENGAL',
#  'WEST BENGAL',
#  'WEST BENGAL',
#  'WEST BENGAL',
#  'WEST BENGAL',
#  'WEST BENGAL',
#  'CHHATTISGARH',
#  'CHHATTISGARH',
#  'CHHATTISGARH',
#  'CHHATTISGARH',
#  'CHHATTISGARH',
#  'CHHATTISGARH',
#  'CHHATTISGARH',
#  'CHHATTISGARH',
#  'CHHATTISGARH',
#  'CHHATTISGARH',
#  'CHHATTISGARH',
#  'CHHATTISGARH',
#  'CHHATTISGARH',
#  'CHHATTISGARH',
#  'CHHATTISGARH',
#  'CHHATTISGARH',
#  'CHHATTISGARH',
#  'CHHATTISGARH',
#  'CHHATTISGARH',
#  'CHHATTISGARH',
#  'CHHATTISGARH',
#  'ASSAM',
#  'ASSAM',
#  'ASSAM',
#  'ASSAM',
#  'ASSAM',
#  'ASSAM',
#  'ASSAM',
#  'ASSAM',
#  'ASSAM',
#  'ASSAM',
#  'ASSAM',
#  'ASSAM',
#  'ASSAM',
#  'ASSAM',
#  'ASSAM',
#  'ASSAM',
#  'ASSAM',
#  'ASSAM',
#  'ASSAM',
#  'ASSAM',
#  'ASSAM',
#  'ASSAM',
#  'ASSAM',
#  'ASSAM',
#  'ASSAM',
#  'ASSAM',
#  'ASSAM',
#  'ASSAM',
#  'ASSAM',
#  'ASSAM',
#  'ASSAM',
#  'ASSAM',
#  'ASSAM',
#  'ASSAM',
#  'ASSAM',
#  'ASSAM',
#  'ASSAM',
#  'ASSAM',
#  'ASSAM',
#  'ASSAM',
#  'ASSAM',
#  'ASSAM',
#  'ASSAM',
#  'ANDHRA PRADESH',
#  'ANDHRA PRADESH',
#  'ANDHRA PRADESH',
#  'ANDHRA PRADESH',
#  'ANDHRA PRADESH',
#  'ANDHRA PRADESH',
#  'ANDHRA PRADESH',
#  'ANDHRA PRADESH',
#  'ANDHRA PRADESH',
#  'ANDHRA PRADESH',
#  'ANDHRA PRADESH',
#  'ANDHRA PRADESH',
#  'ANDHRA PRADESH',
#  'ANDHRA PRADESH',
#  'ANDHRA PRADESH',
#  'ANDHRA PRADESH',
#  'BIHAR',
#  'BIHAR',
#  'BIHAR',
#  'BIHAR',
#  'BIHAR',
#  'BIHAR',
#  'BIHAR',
#  'BIHAR',
#  'BIHAR',
#  'BIHAR',
#  'BIHAR',
#  'BIHAR',
#  'BIHAR',
#  'BIHAR',
#  'BIHAR',
#  'BIHAR',
#  'BIHAR',
#  'BIHAR',
#  'BIHAR',
#  'BIHAR',
#  'BIHAR',
#  'BIHAR',
#  'BIHAR',
#  'BIHAR',
#  'BIHAR',
#  'BIHAR',
#  'BIHAR',
#  'BIHAR',
#  'BIHAR',
#  'BIHAR',
#  'BIHAR',
#  'BIHAR',
#  'BIHAR',
#  'BIHAR',
#  'BIHAR',
#  'BIHAR',
#  'BIHAR',
#  'BIHAR',
#  'BIHAR',
#  'BIHAR',
#  'BIHAR',
#  'BIHAR',
#  'BIHAR',
#  'BIHAR',
#  'BIHAR',
#  'BIHAR',
#  'BIHAR',
#  'BIHAR',
#  'BIHAR',
#  'BIHAR',
#  'BIHAR',
#  'BIHAR',
#  'BIHAR',
#  'BIHAR',
#  'BIHAR',
#  'BIHAR',
#  'BIHAR',
#  'BIHAR',
#  'BIHAR',
#  'BIHAR',
#  'BIHAR']

# %%
labelencoder=LabelEncoder()
labelencoder.fit(states)
labels=labelencoder.transform(states)
data['State Name']=pd.Series(labels)
data
# Out:
#                                           Station Name  State Name  temp_min  \
# 0                                  YAMUNA AT WAZIRABAD           4      16.7
# 1                                 YAMUNA AT NIZAMUDDIN           4      17.1
# 2                  OKHLA BRIDGE (INLET OF\nAGRA CANAL)           4      17.3
# 3               YAMUNA AT OKHLA\nA/M OF SHAHDARA DRAIN           4      19.4
# 4                                 MAHI AT UMETA BRIDGE           5      19.0
# 5                                       MAHI AT MUJPUR           5      27.0
# 6                                      MAHI AT SEVALIA           5      24.0
# 7                                        MAHI AT VASAD           5      20.0
# 8            MAHI NEAR RAJASTHAN BORDER\nAT KADANA DAM           5      29.0
# 9     MAHI AFTER CONF. WITH ANAS AT\nPARDI (BANASWADA)           5      30.0
# 10                                      MAHI AT VIRPUR           5      28.0
# 11                              MAHI AT SHERKHI BRIDGE           5      26.0
# 12       ANAS AT\nDAHOD,(KUSHALGARH),DIST.\nPANCHMAHAL           5      30.0
# 13                                   PANAM AT LUNAWADA           5      28.0
# 14          VISHWAMITRI DOWNSTREAM AT\nKHALIPUR VILLAG           5      26.0
# 15   VISHWAMITRI, UPSTREAM AT\nASOD BRIDGE AT NH-8 ...           5      26.0
# 16                             SABARMATI AT DHAROI DAM           5      27.0
# 17              SABARMATI AT AHMEDABAD AT\nV.N. BRIDGE           5      25.0
# 18                          SABARMATI AT KHEROJ BRIDGE           5      25.0
# 19    SABARMATI A/C WITH MESHWA\nAT VAUTHA NEAR DHOKLA           5      26.0
# 20   SABARMATI AT GANDHI NAGAR\nCHILODA BRIDGE,LEKA...           5      28.0
# 21   SABARMATI AT VILL. MIROLI\nTALUKA DASCROI,AHME...           5      28.0
# 22              SABARMATI AT RAILWAY BRIDGE\nAHMEDABAD           5      25.0
# 23   SABARMATI AT MAHUDI JAIN\nTEMPLE, 150 KM. FORM...           5      27.0
# 24                         SABARMATI AT HANSAOL BRIDGE           5      25.0
# 25            MESHWA NEAR RAJASTHAN\nBORDER AT SAMLAJI           5      27.0
# 26                                     SHEDHI AT KHEDA           5      25.0
# 27                              NARMADA AT GARUDESHWAR           5      26.0
# 28                                  NARMADA AT CHANDOD           5      25.0
# 29                                  NARMADA AT PANETHA           5      26.0
# ..                                                 ...         ...       ...
# 757                   KAMALA AT BENIPATTI\n(MADHUBANI)           2      15.0
# 758                                KAMALA AT DARBHANGA           2      17.0
# 759                        MANUSMARAT RIGA,\nSITAMARHI           2      18.0
# 760                      KOSHI AT KURSHELA AT\nKATIHAR           2      14.0
# 761                                 KOSHI AT MADHEPURA           2      14.0
# 762                                      DAHA AT SIWAN           2      15.0
# 763                                  DAHA D/S SASAMUSA           2      16.0
# 764                        DAHA AT ITWA BRIDGE,\nSIWAN           2      15.0
# 765                                 DHOUS AT MADHUBANI           2      18.0
# 766                                  FARMAR AT JOGBANI           2      14.0
# 767                              RAM REKHAAT HARINAGAR           2      16.0
# 768                                     SIRSA AT RUXOL           2      16.0
# 769                                  SONE NEAR BANZARI           2      16.0
# 770                             SONE RIVER AT BAHIYARA           2      22.0
# 771                      SONE RIVER AT NASIRIGANJ\nDAM           2      18.0
# 772     BAGMATI AT MUZAFFARPUR-\nSITAMARHI ROAD BRIDGE           2      16.0
# 773       BAGMATI AT DARBANGA,\nSAMASTIPUR ROAD BRIDGE           2      20.0
# 774                                   DAHA AT MEERGANJ           2      15.0
# 775           GANDAK U/S ROAD BRIDGE\nMUZAFFARPUR (NH)           2      17.0
# 776  GANDAK GOPALGANJ PIPRAKOTHI\nROAD BRIDGE (DUMA...           2      17.0
# 777  U/S HARBORA BEFORE SUGAR MILL\nNEAR ROAD BRIDG...           2      16.0
# 778                                KAMALA AT JAYNAGAR,           2      20.0
# 779                                   KOSHI AT BEERPUR           2      14.0
# 780                U/S MANUSMAR RIVER AT BAKHARI\nRIGA           2      15.0
# 781                  POONPUN NEAR POONPUN RAIL\nBRIDGE           2      12.0
# 782                   POONPUN NEAR KINZER ROAD\nBRIDGE           2      14.0
# 783                             RAMREKHA U/S HARINAGAR           2      16.0
# 784         SIKRAHNA AT LAUREA, HARINAGAR\nROAD BRIDGE           2      17.0
# 785                     SIRSA D/S RAXAUL (KOERIA TOLA)           2      16.0
# 786   MAHANANDA AT THAKURGANJ,\nKISHANGANJ ROAD BRIDGE           2      14.0
#
#      temp_max   bact grow  oxy_min  oxy_max  ph_min  ph_max
# 0        32.8           1      5.1    13.50     7.2     8.0
# 1        30.9           0      0.4     2.60     7.1     7.9
# 2        30.4           0      0.4     1.80     7.1     7.8
# 3        31.8           0      0.1     1.60     7.0     7.9
# 4        30.0           1      5.3     9.00     7.3     8.5
# 5        33.0           1      6.0     9.00     8.0     8.6
# 6        30.0           1      7.3     9.00     7.3     8.5
# 7        29.0           1      4.9     9.10     7.3     8.5
# 8        32.0           1      6.2     9.00     7.1     8.5
# 9        33.0           1      5.6     8.90     7.5     8.5
# 10       32.0           0      3.0     8.90     7.8     8.3
# 11       31.0           1      6.0     9.00     7.1     8.7
# 12       32.0           0      3.8     8.90     7.6     8.5
# 13       32.0           1      5.6     9.00     7.0     8.1
# 14       30.0           0      0.8     2.20     7.8     8.3
# 15       30.0           1      4.9     9.20     7.7     8.9
# 16       33.0           1      5.5     8.04     7.5     8.0
# 17       29.0           0      1.2     7.32     7.4     8.5
# 18       27.0           0      4.1     7.70     7.4     8.4
# 19       30.0           0      1.1     7.20     7.9     8.5
# 20       32.0           1      5.0     8.20     7.4     8.8
# 21       33.0           1      7.1     7.10     8.0     8.4
# 22       28.0           0      3.4     7.20     7.8     8.4
# 23       29.0           0      4.0     8.80     7.3     8.3
# 24       28.0           0      4.3     7.60     8.0     8.0
# 25       27.0           1      6.6     6.60     7.3     8.1
# 26       32.0           0      1.2     9.00     7.7     8.4
# 27       30.0           1      7.1     7.95     7.1     8.5
# 28       30.0           1      5.8     8.50     7.0     8.4
# 29       32.0           1      7.0     8.20     7.5     8.3
# ..        ...         ...      ...      ...     ...     ...
# 757      30.0           1      7.4    10.00     7.6     8.9
# 758      30.0           1      7.0     8.60     7.3     8.2
# 759      32.0           1      6.7     8.00     6.8     8.2
# 760      31.0           1      6.3     9.10     6.6     7.6
# 761      35.0           1      6.2     9.00     7.2     7.6
# 762      30.0           1      5.0     9.80     7.1     8.4
# 763      30.0           1      6.0     9.50     7.0     7.8
# 764      29.0           1      6.9     9.20     7.2     8.4
# 765      30.0           1      6.0     9.40     7.3     8.9
# 766      29.0           1      5.6     8.60     6.6     7.6
# 767      32.0           1      6.4     7.60     6.9     7.9
# 768      33.0           1      6.4     6.40     7.0     7.7
# 769      34.0           1      7.2     9.20     7.2     8.6
# 770      30.0           1      5.2     9.00     7.5     8.2
# 771      33.0           1      7.1     9.60     7.4     8.5
# 772      35.0           1      7.2     8.80     6.9     8.2
# 773      34.0           1      7.4     9.10     7.4     8.8
# 774      30.0           1      6.5     9.60     7.5     8.2
# 775      33.0           1      7.5     8.80     7.2     8.4
# 776      30.0           1      7.0     9.80     7.3     8.6
# 777      30.0           1      7.2     8.60     7.1     8.3
# 778      29.0           1      7.5    10.00     7.7     8.5
# 779      35.0           0      6.6     8.90     7.2     7.8
# 780      32.0           1      7.0     8.60     7.0     8.6
# 781      30.0           1      6.5     9.60     7.0     8.6
# 782      32.0           1      6.5    10.00     7.1     8.5
# 783      32.0           1      6.9     8.00     7.1     7.9
# 784      36.0           0      7.0     8.60     7.2     7.8
# 785      36.0           0      2.8     6.30     7.2     7.8
# 786      28.0           1      6.1     8.50     6.5     7.6
#
# [787 rows x 9 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import numpy as np
sns.set(style="whitegrid", color_codes=True)
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.countplot('State Name',data=data,hue = ' bact grow')
plt.xlabel("states")
plt.ylabel("bact count")
plt.title("bacteria count in different states")
plt.grid()
labels=['low','high']
s=['andhra-pradesh', 'assam', 'bihar', 'chhattisgarh', 'delhi', 'gujarat', 'haryana', 
'himachal-pradesh', 'jammu & kashmir', 'jharkhand', 'karnataka', 'kerala', 'madhya-pradesh', 
'maharashtra', 'nagaland', 'odisha', 'punjab', 'rajasthan', 'tamil-nadu', 'telangana',
'tripura', 'uttarakhand', 'uttar-pradesh', 'west-bengal']
x=np.arange(len(s))
plt.xticks(x,s,rotation=40)
plt.legend(labels)

# %%
sns.set(rc={'figure.figsize':(16.7,13.27)})
sns.violinplot(x="bact",y="State Name", hue="bact", data=data);
label=['low','high']
plt.show()

# %%
ax=sns.boxplot('bact','State Name',data=data,hue='bact')
ax.set_title("bacteria count")
ax.set_ylabel("states")
ax.set_xlabel("bacteria growth")
# Out:
# Text(0.5,0,'bacteria growth')

# %%
sns.stripplot(x='bact',y='State Name',data=data)

# %%
sns.swarmplot(x=' bact grow',y='State Name',data=data)

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
#data['Station Name']=le.fit_transform(data['Station Name'])
data['temp_min']=le.fit_transform(data['temp_min'])
data['oxy_min']=le.fit_transform(data['oxy_min'])
data['temp_min']=le.fit_transform(data['ph_min'])
data['temp_max']=le.fit_transform(data['temp_max'])
data['oxy_max']=le.fit_transform(data['oxy_max'])
data['ph_max']=le.fit_transform(data['ph_max'])
data
# Out:
#                                           Station Name  State Name  temp_min  \
# 0                                  YAMUNA AT WAZIRABAD           4        14
# 1                                 YAMUNA AT NIZAMUDDIN           4        13
# 2                  OKHLA BRIDGE (INLET OF\nAGRA CANAL)           4        13
# 3               YAMUNA AT OKHLA\nA/M OF SHAHDARA DRAIN           4        12
# 4                                 MAHI AT UMETA BRIDGE           5        15
# 5                                       MAHI AT MUJPUR           5        22
# 6                                      MAHI AT SEVALIA           5        15
# 7                                        MAHI AT VASAD           5        15
# 8            MAHI NEAR RAJASTHAN BORDER\nAT KADANA DAM           5        13
# 9     MAHI AFTER CONF. WITH ANAS AT\nPARDI (BANASWADA)           5        17
# 10                                      MAHI AT VIRPUR           5        20
# 11                              MAHI AT SHERKHI BRIDGE           5        13
# 12       ANAS AT\nDAHOD,(KUSHALGARH),DIST.\nPANCHMAHAL           5        18
# 13                                   PANAM AT LUNAWADA           5        12
# 14          VISHWAMITRI DOWNSTREAM AT\nKHALIPUR VILLAG           5        20
# 15   VISHWAMITRI, UPSTREAM AT\nASOD BRIDGE AT NH-8 ...           5        19
# 16                             SABARMATI AT DHAROI DAM           5        17
# 17              SABARMATI AT AHMEDABAD AT\nV.N. BRIDGE           5        16
# 18                          SABARMATI AT KHEROJ BRIDGE           5        16
# 19    SABARMATI A/C WITH MESHWA\nAT VAUTHA NEAR DHOKLA           5        21
# 20   SABARMATI AT GANDHI NAGAR\nCHILODA BRIDGE,LEKA...           5        16
# 21   SABARMATI AT VILL. MIROLI\nTALUKA DASCROI,AHME...           5        22
# 22              SABARMATI AT RAILWAY BRIDGE\nAHMEDABAD           5        20
# 23   SABARMATI AT MAHUDI JAIN\nTEMPLE, 150 KM. FORM...           5        15
# 24                         SABARMATI AT HANSAOL BRIDGE           5        22
# 25            MESHWA NEAR RAJASTHAN\nBORDER AT SAMLAJI           5        15
# 26                                     SHEDHI AT KHEDA           5        19
# 27                              NARMADA AT GARUDESHWAR           5        13
# 28                                  NARMADA AT CHANDOD           5        12
# 29                                  NARMADA AT PANETHA           5        17
# ..                                                 ...         ...       ...
# 757                   KAMALA AT BENIPATTI\n(MADHUBANI)           2        18
# 758                                KAMALA AT DARBHANGA           2        15
# 759                        MANUSMARAT RIGA,\nSITAMARHI           2        10
# 760                      KOSHI AT KURSHELA AT\nKATIHAR           2         8
# 761                                 KOSHI AT MADHEPURA           2        14
# 762                                      DAHA AT SIWAN           2        13
# 763                                  DAHA D/S SASAMUSA           2        12
# 764                        DAHA AT ITWA BRIDGE,\nSIWAN           2        14
# 765                                 DHOUS AT MADHUBANI           2        15
# 766                                  FARMAR AT JOGBANI           2         8
# 767                              RAM REKHAAT HARINAGAR           2        11
# 768                                     SIRSA AT RUXOL           2        12
# 769                                  SONE NEAR BANZARI           2        14
# 770                             SONE RIVER AT BAHIYARA           2        17
# 771                      SONE RIVER AT NASIRIGANJ\nDAM           2        16
# 772     BAGMATI AT MUZAFFARPUR-\nSITAMARHI ROAD BRIDGE           2        11
# 773       BAGMATI AT DARBANGA,\nSAMASTIPUR ROAD BRIDGE           2        16
# 774                                   DAHA AT MEERGANJ           2        17
# 775           GANDAK U/S ROAD BRIDGE\nMUZAFFARPUR (NH)           2        14
# 776  GANDAK GOPALGANJ PIPRAKOTHI\nROAD BRIDGE (DUMA...           2        15
# 777  U/S HARBORA BEFORE SUGAR MILL\nNEAR ROAD BRIDG...           2        13
# 778                                KAMALA AT JAYNAGAR,           2        19
# 779                                   KOSHI AT BEERPUR           2        14
# 780                U/S MANUSMAR RIVER AT BAKHARI\nRIGA           2        12
# 781                  POONPUN NEAR POONPUN RAIL\nBRIDGE           2        12
# 782                   POONPUN NEAR KINZER ROAD\nBRIDGE           2        13
# 783                             RAMREKHA U/S HARINAGAR           2        13
# 784         SIKRAHNA AT LAUREA, HARINAGAR\nROAD BRIDGE           2        14
# 785                     SIRSA D/S RAXAUL (KOERIA TOLA)           2        14
# 786   MAHANANDA AT THAKURGANJ,\nKISHANGANJ ROAD BRIDGE           2         7
#
#      temp_max   bact grow  oxy_min  oxy_max  ph_min  ph_max
# 0          34           1       50       96     7.2      11
# 1          30           0        4       10     7.1      10
# 2          29           0        4        4     7.1       9
# 3          32           0        1        3     7.0      10
# 4          28           1       52       63     7.3      16
# 5          35           1       59       63     8.0      17
# 6          28           1       72       63     7.3      16
# 7          27           1       48       64     7.3      16
# 8          33           1       61       63     7.1      16
# 9          35           1       55       62     7.5      16
# 10         33           0       29       62     7.8      14
# 11         31           1       59       63     7.1      18
# 12         33           0       37       62     7.6      16
# 13         33           1       55       63     7.0      12
# 14         28           0        8        7     7.8      14
# 15         28           1       48       65     7.7      20
# 16         35           1       54       53     7.5      11
# 17         27           0       12       44     7.4      16
# 18         23           0       40       48     7.4      15
# 19         28           0       11       42     7.9      16
# 20         33           1       49       55     7.4      19
# 21         35           1       70       41     8.0      15
# 22         25           0       33       42     7.8      15
# 23         27           0       39       61     7.3      14
# 24         25           0       42       47     8.0      11
# 25         23           1       65       35     7.3      12
# 26         33           0       12       63     7.7      15
# 27         28           1       70       51     7.1      16
# 28         28           1       57       58     7.0      15
# 29         33           1       69       55     7.5      14
# ..        ...         ...      ...      ...     ...     ...
# 757        28           1       73       74     7.6      20
# 758        28           1       69       59     7.3      13
# 759        33           1       66       52     6.8      13
# 760        31           1       62       64     6.6       7
# 761        37           1       61       63     7.2       7
# 762        28           1       49       72     7.1      15
# 763        28           1       59       68     7.0       9
# 764        27           1       68       65     7.2      15
# 765        28           1       59       67     7.3      20
# 766        27           1       55       59     6.6       7
# 767        33           1       63       47     6.9      10
# 768        35           1       63       33     7.0       8
# 769        36           1       71       65     7.2      17
# 770        28           1       51       63     7.5      13
# 771        35           1       70       69     7.4      16
# 772        37           1       71       61     6.9      13
# 773        36           1       73       64     7.4      19
# 774        28           1       64       69     7.5      13
# 775        35           1       74       61     7.2      15
# 776        28           1       69       72     7.3      17
# 777        28           1       71       59     7.1      14
# 778        27           1       74       74     7.7      16
# 779        37           0       65       62     7.2       9
# 780        33           1       69       59     7.0      17
# 781        28           1       64       69     7.0      17
# 782        33           1       64       74     7.1      16
# 783        33           1       68       52     7.1      10
# 784        38           0       69       59     7.2       9
# 785        38           0       27       32     7.2       9
# 786        25           1       60       58     6.5       7
#
# [787 rows x 9 columns]

# %%
cols = [col for col in data.columns if col not in [' bact grow','Station Name']]
cols
# Out:
# ['State Name',
#  'temp_min',
#  'temp_max',
#  'oxy_min',
#  'oxy_max',
#  'ph_min',
#  'ph_max']

# %%
x=data[cols]
y=data[' bact grow']
x
# Out:
#      State Name  temp_min  temp_max  oxy_min  oxy_max  ph_min  ph_max
# 0             4        14        34       50       96     7.2      11
# 1             4        13        30        4       10     7.1      10
# 2             4        13        29        4        4     7.1       9
# 3             4        12        32        1        3     7.0      10
# 4             5        15        28       52       63     7.3      16
# 5             5        22        35       59       63     8.0      17
# 6             5        15        28       72       63     7.3      16
# 7             5        15        27       48       64     7.3      16
# 8             5        13        33       61       63     7.1      16
# 9             5        17        35       55       62     7.5      16
# 10            5        20        33       29       62     7.8      14
# 11            5        13        31       59       63     7.1      18
# 12            5        18        33       37       62     7.6      16
# 13            5        12        33       55       63     7.0      12
# 14            5        20        28        8        7     7.8      14
# 15            5        19        28       48       65     7.7      20
# 16            5        17        35       54       53     7.5      11
# 17            5        16        27       12       44     7.4      16
# 18            5        16        23       40       48     7.4      15
# 19            5        21        28       11       42     7.9      16
# 20            5        16        33       49       55     7.4      19
# 21            5        22        35       70       41     8.0      15
# 22            5        20        25       33       42     7.8      15
# 23            5        15        27       39       61     7.3      14
# 24            5        22        25       42       47     8.0      11
# 25            5        15        23       65       35     7.3      12
# 26            5        19        33       12       63     7.7      15
# 27            5        13        28       70       51     7.1      16
# 28            5        12        28       57       58     7.0      15
# 29            5        17        33       69       55     7.5      14
# ..          ...       ...       ...      ...      ...     ...     ...
# 757           2        18        28       73       74     7.6      20
# 758           2        15        28       69       59     7.3      13
# 759           2        10        33       66       52     6.8      13
# 760           2         8        31       62       64     6.6       7
# 761           2        14        37       61       63     7.2       7
# 762           2        13        28       49       72     7.1      15
# 763           2        12        28       59       68     7.0       9
# 764           2        14        27       68       65     7.2      15
# 765           2        15        28       59       67     7.3      20
# 766           2         8        27       55       59     6.6       7
# 767           2        11        33       63       47     6.9      10
# 768           2        12        35       63       33     7.0       8
# 769           2        14        36       71       65     7.2      17
# 770           2        17        28       51       63     7.5      13
# 771           2        16        35       70       69     7.4      16
# 772           2        11        37       71       61     6.9      13
# 773           2        16        36       73       64     7.4      19
# 774           2        17        28       64       69     7.5      13
# 775           2        14        35       74       61     7.2      15
# 776           2        15        28       69       72     7.3      17
# 777           2        13        28       71       59     7.1      14
# 778           2        19        27       74       74     7.7      16
# 779           2        14        37       65       62     7.2       9
# 780           2        12        33       69       59     7.0      17
# 781           2        12        28       64       69     7.0      17
# 782           2        13        33       64       74     7.1      16
# 783           2        13        33       68       52     7.1      10
# 784           2        14        38       69       59     7.2       9
# 785           2        14        38       27       32     7.2       9
# 786           2         7        25       60       58     6.5       7
#
# [787 rows x 7 columns]

# %%
from sklearn.model_selection import train_test_split
data_train, data_test, target_train, target_test = train_test_split(x,y, test_size = 0.20, random_state = 10)

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score
gnb = GaussianNB()
pred = gnb.fit(data_train, target_train).predict(data_test)
print("Naive-Bayes accuracy : ",accuracy_score(target_test, pred, normalize = True))
# Out:
# Naive-Bayes accuracy :  0.8670886075949367

# %%
# Naive Bayes
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
classifier.fit(data_train, target_train)
 
y_pred = classifier.predict(data_test)
 
# Summary of the predictions made by the classifier
print(classification_report(target_test, y_pred))
print(confusion_matrix(target_test, y_pred))
# Accuracy score
from sklearn.metrics import accuracy_score
print('accuracy is',accuracy_score(y_pred,target_test))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.88      0.74      0.80        57
#           1       0.86      0.94      0.90       101
#
# avg / total       0.87      0.87      0.86       158
#
# [[42 15]
#  [ 6 95]]
# accuracy is 0.8670886075949367

# %%
from yellowbrick.classifier import ClassificationReport
# Instantiate the classification model and visualizer
visualizer = ClassificationReport(gnb, classes=['low bact growth','high bact growth'])
visualizer.fit(data_train, target_train) # Fit the training data to the visualizer
visualizer.score(data_test, target_test) # Evaluate the model on the test data
g = visualizer.poof() # Draw/show/poof the data

# %%
from sklearn.svm import LinearSVC
from sklearn.metrics import accuracy_score
svc_model = LinearSVC(random_state=0)
pred = svc_model.fit(data_train, target_train).predict(data_test)
print("LinearSVC accuracy : ",accuracy_score(target_test, pred, normalize = True))
# Out:
# LinearSVC accuracy :  0.7278481012658228

# %%
# Linear SVC
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.svm import LinearSVC
classifier = LinearSVC(random_state=0)
classifier.fit(data_train, target_train)
 
y_pred = classifier.predict(data_test)
 
# Summary of the predictions made by the classifier
print(classification_report(target_test, y_pred))
print(confusion_matrix(target_test, y_pred))
# Accuracy score
from sklearn.metrics import accuracy_score
print('accuracy is',accuracy_score(y_pred,target_test))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.94      0.26      0.41        57
#           1       0.70      0.99      0.82       101
#
# avg / total       0.79      0.73      0.67       158
#
# [[ 15  42]
#  [  1 100]]
# accuracy is 0.7278481012658228

# %%
from yellowbrick.classifier import ClassificationReport
# Instantiate the classification model and visualizer
visualizer = ClassificationReport(svc_model, classes=['bact low','bact high'])
visualizer.fit(data_train, target_train) # Fit the training data to the visualizer
visualizer.score(data_test, target_test) # Evaluate the model on the test data
g = visualizer.poof() # Draw/show/poof the data

# %%
#import necessary modules
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
#create object of the lassifier
neigh = KNeighborsClassifier(n_neighbors=2)
#Train the algorithm
neigh.fit(data_train, target_train)
# predict the response
pred = neigh.predict(data_test)
# evaluate accuracy
print ("KNeighbors accuracy score : ",accuracy_score(target_test, pred))
# Out:
# KNeighbors accuracy score :  0.8734177215189873

# %%
# K neighbors
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier()
classifier.fit(data_train, target_train)
 
y_pred = classifier.predict(data_test)
 
# Summary of the predictions made by the classifier
print(classification_report(target_test, y_pred))
print(confusion_matrix(target_test, y_pred))
# Accuracy score
from sklearn.metrics import accuracy_score
print('accuracy is',accuracy_score(y_pred,target_test))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.87      0.81      0.84        57
#           1       0.90      0.93      0.91       101
#
# avg / total       0.89      0.89      0.89       158
#
# [[46 11]
#  [ 7 94]]
# accuracy is 0.8860759493670886

# %%
from yellowbrick.classifier import ClassificationReport
# Instantiate the classification model and visualizer
visualizer = ClassificationReport(neigh, classes=['high bact','low bact'])
visualizer.fit(data_train, target_train) # Fit the training data to the visualizer
visualizer.score(data_test, target_test) # Evaluate the model on the test data
g = visualizer.poof() # Draw/show/poof the data

# %%
import pandas as pd
data1=pd.read_csv("2016_mod.csv")
data1

# %%
cols = [col for col in data1.columns if col not in ['bact grow','Station Name','State Name']]
cols
# Out:
# ['temp_min', 'temp_max', 'oxy_min', 'oxy_max', 'ph_min', 'ph_max']

# %%
X=data1[cols]
y=data['bact grow']
X
# Out:
#      temp_min  temp_max  oxy_min  oxy_max  ph_min  ph_max
# 0        16.7      32.8      5.1    13.50     7.2     8.0
# 1        17.1      30.9      0.4     2.60     7.1     7.9
# 2        17.3      30.4      0.4     1.80     7.1     7.8
# 3        19.4      31.8      0.1     1.60     7.0     7.9
# 4        19.0      30.0      5.3     9.00     7.3     8.5
# 5        27.0      33.0      6.0     9.00     8.0     8.6
# 6        24.0      30.0      7.3     9.00     7.3     8.5
# 7        20.0      29.0      4.9     9.10     7.3     8.5
# 8        29.0      32.0      6.2     9.00     7.1     8.5
# 9        30.0      33.0      5.6     8.90     7.5     8.5
# 10       28.0      32.0      3.0     8.90     7.8     8.3
# 11       26.0      31.0      6.0     9.00     7.1     8.7
# 12       30.0      32.0      3.8     8.90     7.6     8.5
# 13       28.0      32.0      5.6     9.00     7.0     8.1
# 14       26.0      30.0      0.8     2.20     7.8     8.3
# 15       26.0      30.0      4.9     9.20     7.7     8.9
# 16       27.0      33.0      5.5     8.04     7.5     8.0
# 17       25.0      29.0      1.2     7.32     7.4     8.5
# 18       25.0      27.0      4.1     7.70     7.4     8.4
# 19       26.0      30.0      1.1     7.20     7.9     8.5
# 20       28.0      32.0      5.0     8.20     7.4     8.8
# 21       28.0      33.0      7.1     7.10     8.0     8.4
# 22       25.0      28.0      3.4     7.20     7.8     8.4
# 23       27.0      29.0      4.0     8.80     7.3     8.3
# 24       25.0      28.0      4.3     7.60     8.0     8.0
# 25       27.0      27.0      6.6     6.60     7.3     8.1
# 26       25.0      32.0      1.2     9.00     7.7     8.4
# 27       26.0      30.0      7.1     7.95     7.1     8.5
# 28       25.0      30.0      5.8     8.50     7.0     8.4
# 29       26.0      32.0      7.0     8.20     7.5     8.3
# ..        ...       ...      ...      ...     ...     ...
# 757      15.0      30.0      7.4    10.00     7.6     8.9
# 758      17.0      30.0      7.0     8.60     7.3     8.2
# 759      18.0      32.0      6.7     8.00     6.8     8.2
# 760      14.0      31.0      6.3     9.10     6.6     7.6
# 761      14.0      35.0      6.2     9.00     7.2     7.6
# 762      15.0      30.0      5.0     9.80     7.1     8.4
# 763      16.0      30.0      6.0     9.50     7.0     7.8
# 764      15.0      29.0      6.9     9.20     7.2     8.4
# 765      18.0      30.0      6.0     9.40     7.3     8.9
# 766      14.0      29.0      5.6     8.60     6.6     7.6
# 767      16.0      32.0      6.4     7.60     6.9     7.9
# 768      16.0      33.0      6.4     6.40     7.0     7.7
# 769      16.0      34.0      7.2     9.20     7.2     8.6
# 770      22.0      30.0      5.2     9.00     7.5     8.2
# 771      18.0      33.0      7.1     9.60     7.4     8.5
# 772      16.0      35.0      7.2     8.80     6.9     8.2
# 773      20.0      34.0      7.4     9.10     7.4     8.8
# 774      15.0      30.0      6.5     9.60     7.5     8.2
# 775      17.0      33.0      7.5     8.80     7.2     8.4
# 776      17.0      30.0      7.0     9.80     7.3     8.6
# 777      16.0      30.0      7.2     8.60     7.1     8.3
# 778      20.0      29.0      7.5    10.00     7.7     8.5
# 779      14.0      35.0      6.6     8.90     7.2     7.8
# 780      15.0      32.0      7.0     8.60     7.0     8.6
# 781      12.0      30.0      6.5     9.60     7.0     8.6
# 782      14.0      32.0      6.5    10.00     7.1     8.5
# 783      16.0      32.0      6.9     8.00     7.1     7.9
# 784      17.0      36.0      7.0     8.60     7.2     7.8
# 785      16.0      36.0      2.8     6.30     7.2     7.8
# 786      14.0      28.0      6.1     8.50     6.5     7.6
#
# [787 rows x 6 columns]

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
model.fit(X,y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
predictions=model.predict(X)
predictions
# Out:
# array(['high', 'low', 'low', 'low', 'high', 'high', 'high', 'high',
#        'high', 'high', 'low', 'high', 'low', 'high', 'low', 'high',
#        'high', 'low', 'low', 'low', 'high', 'high', 'low', 'low', 'low',
#        'high', 'low', 'high', 'high', 'high', 'high', 'high', 'high',
#        'low', 'low', 'high', 'high', 'high', 'low', 'high', 'high',
#        'high', 'high', 'high', 'high', 'low', 'low', 'low', 'high',
#        'high', 'high', 'low', 'high', 'low', 'high', 'high', 'high',
#        'low', 'high', 'low', 'low', 'low', 'high', 'high', 'low', 'high',
#        'high', 'high', 'high', 'high', 'low', 'low', 'low', 'low', 'high',
#        'high', 'high', 'high', 'high', 'high', 'low', 'high', 'low',
#        'high', 'low', 'high', 'high', 'high', 'high', 'low', 'low', 'low',
#        'high', 'low', 'high', 'high', 'high', 'high', 'low', 'high',
#        'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high',
#        'high', 'low', 'low', 'low', 'low', 'low', 'high', 'high', 'high',
#        'high', 'high', 'high', 'high', 'high', 'low', 'low', 'high',
#        'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high',
#        'high', 'high', 'low', 'high', 'high', 'high', 'high', 'high',
#        'high', 'high', 'low', 'high', 'low', 'low', 'low', 'low', 'high',
#        'high', 'low', 'low', 'low', 'high', 'high', 'low', 'high', 'high',
#        'high', 'high', 'high', 'low', 'high', 'high', 'low', 'high',
#        'high', 'high', 'high', 'low', 'high', 'high', 'low', 'high',
#        'high', 'high', 'high', 'low', 'high', 'low', 'high', 'high',
#        'high', 'high', 'high', 'high', 'high', 'low', 'low', 'high',
#        'high', 'high', 'low', 'low', 'high', 'high', 'high', 'high',
#        'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high',
#        'high', 'high', 'high', 'high', 'high', 'low', 'high', 'high',
#        'low', 'high', 'low', 'low', 'low', 'low', 'high', 'high', 'high',
#        'low', 'high', 'high', 'high', 'high', 'high', 'high', 'high',
#        'low', 'high', 'high', 'high', 'high', 'high', 'high', 'high',
#        'high', 'high', 'low', 'low', 'low', 'low', 'low', 'high', 'high',
#        'high', 'high', 'high', 'high', 'low', 'low', 'high', 'high',
#        'high', 'low', 'high', 'high', 'low', 'low', 'high', 'low', 'low',
#        'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high',
#        'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high',
#        'high', 'high', 'high', 'high', 'high', 'low', 'high', 'high',
#        'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high',
#        'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high',
#        'high', 'high', 'high', 'high', 'high', 'high', 'low', 'high',
#        'high', 'low', 'low', 'low', 'high', 'low', 'high', 'high', 'high',
#        'high', 'high', 'low', 'low', 'low', 'low', 'low', 'low', 'low',
#        'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low',
#        'low', 'low', 'high', 'high', 'high', 'high', 'high', 'low', 'low',
#        'low', 'low', 'low', 'low', 'high', 'high', 'low', 'high', 'high',
#        'high', 'low', 'low', 'low', 'low', 'high', 'high', 'high', 'low',
#        'low', 'low', 'low', 'low', 'low', 'high', 'low', 'low', 'high',
#        'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low',
#        'low', 'low', 'low', 'low', 'high', 'low', 'low', 'low', 'low',
#        'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low',
#        'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low',
#        'low', 'high', 'low', 'low', 'low', 'low', 'low', 'low', 'low',
#        'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low',
#        'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low',
#        'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high',
#        'high', 'high', 'high', 'low', 'high', 'high', 'high', 'high',
#        'high', 'high', 'high', 'low', 'high', 'low', 'high', 'high',
#        'high', 'low', 'low', 'low', 'low', 'low', 'low', 'high', 'low',
#        'low', 'low', 'low', 'low', 'low', 'high', 'low', 'high', 'low',
#        'high', 'low', 'low', 'low', 'high', 'low', 'high', 'high', 'high',
#        'low', 'low', 'high', 'high', 'high', 'low', 'high', 'high', 'low',
#        'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high',
#        'high', 'low', 'low', 'high', 'high', 'low', 'high', 'high',
#        'high', 'high', 'high', 'high', 'high', 'low', 'low', 'low',
#        'high', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'high',
#        'high', 'high', 'high', 'high', 'high', 'high', 'low', 'high',
#        'low', 'high', 'low', 'high', 'high', 'high', 'high', 'high',
#        'low', 'high', 'high', 'high', 'high', 'low', 'low', 'low', 'low',
#        'low', 'low', 'high', 'high', 'low', 'high', 'high', 'high',
#        'high', 'low', 'high', 'high', 'high', 'high', 'low', 'high',
#        'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high',
#        'low', 'low', 'high', 'high', 'high', 'high', 'high', 'high',
#        'high', 'high', 'high', 'high', 'high', 'low', 'low', 'low',
#        'high', 'high', 'high', 'high', 'low', 'low', 'low', 'low', 'high',
#        'low', 'high', 'low', 'high', 'low', 'low', 'low', 'low', 'low',
#        'low', 'low', 'low', 'low', 'high', 'high', 'high', 'low', 'low',
#        'high', 'high', 'high', 'high', 'high', 'high', 'low', 'low',
#        'low', 'low', 'low', 'low', 'low', 'high', 'low', 'low', 'low',
#        'low', 'low', 'high', 'high', 'high', 'high', 'low', 'high',
#        'high', 'low', 'low', 'high', 'high', 'high', 'high', 'low',
#        'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high',
#        'high', 'low', 'high', 'high', 'high', 'high', 'high', 'high',
#        'high', 'high', 'high', 'high', 'high', 'high', 'high', 'low',
#        'high', 'high', 'high', 'high', 'high', 'high', 'low', 'low',
#        'high', 'low', 'low', 'high', 'high', 'low', 'low', 'high', 'low',
#        'low', 'high', 'high', 'high', 'high', 'high', 'high', 'high',
#        'low', 'high', 'high', 'high', 'high', 'low', 'low', 'high',
#        'high', 'high', 'high', 'high', 'high', 'low', 'low', 'low', 'low',
#        'low', 'low', 'high', 'low', 'high', 'high', 'high', 'high',
#        'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high',
#        'low', 'high', 'high', 'high', 'high', 'high', 'high', 'high',
#        'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high',
#        'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high',
#        'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high',
#        'high', 'high', 'high', 'high', 'high', 'high', 'high', 'low',
#        'high', 'high', 'high', 'high', 'low', 'low', 'high'], dtype=object)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)
model = DecisionTreeClassifier()
model.fit(X_train,y_train)
predictions1= model.predict(X_test)
from sklearn.metrics import accuracy_score
score= accuracy_score(y_test,predictions1)
score
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-160e51fde22d> in <module>()
#       1 from sklearn.model_selection import train_test_split
# ----> 2 X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)
#       3 model = DecisionTreeClassifier()
#       4 model.fit(X_train,y_train)
#       5 predictions1= model.predict(X_test)
#
# NameError: name 'X' is not defined

# %%
# visualization of our decision tree
from sklearn import tree
# tree is a method for exploring our decision tree in a graphical format
dot_data =tree.export_graphviz(model,out_file='water_model_2020.dot'
                     ,feature_names=['temp_min', 'temp_max', 'oxy_min', 'oxy_max', 'ph_min', 'ph_max']
                     ,class_names=sorted(y.unique())
                     ,label='all',rounded=True
                     ,filled=True)
